# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (20, 6)
# df1 = pd.read_csv("https://ritoweb-public.s3.ap-northeast-1.amazonaws.com/session-20220506-130154-mizunami-v3.csv", usecols=["x_acc", "y_acc", "z_acc", "timestamp"])
# print('racechrono csv v3')

# plt.plot(df1["timestamp"], df1["y_acc"])
# df2 = pd.read_json("https://ritoweb-public.s3.ap-northeast-1.amazonaws.com/normal.txt")
# plt.plot(df2["y"], alpha=1)

df3 = pd.read_json("https://ritoweb-public.s3.ap-northeast-1.amazonaws.com/test+5.txt")

x = df3['x']

plt.plot(x, alpha=1)
n = 12 #移動平均の点数
ave = np.convolve(x, np.ones(n)/float(n), 'same')
plt.plot(ave, alpha=1)

plt.legend(['x', 'x-move-ave'],fontsize=12,loc=1)
